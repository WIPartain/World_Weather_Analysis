# %%
pip install citipy
# Out:
# Collecting citipy
#   Using cached citipy-0.0.5-py3-none-any.whl
# Collecting kdtree>=0.12
#   Using cached kdtree-0.16-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 644

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#counters for counting records in sets
record_count=1
set_count = 1

# empty dictionary to collect info 
weather_dict = {"Cities": [], "Country": [], "Latitude": [], "Date": [],"Max. Temperature": [], "Humidity": [], 
                           "Cloudiness": [], "Wind Speed": []}

print(" Beginning Data Retrieval \n-----------------------------")

for city_index in range(len(cities)):
    
        city_url= cities[city_index].replace(" ", "%20")  #--to format cities names with more than one word
        weather_response = requests.get(query_url+city_url).json()
        print(query_url+city_url)
        
        if weather_response['cod']=='404':
            print("City not found. Skipping...")
        else:
            print(f"Processing Record {record_count} of Set {set_count} | {cities[city_index]}")
            try:
                date = time.strftime('%m-%d-%y', time.localtime(weather_response['dt'])) # to collect only date component
                weather_dict["Date"].append(date)
                weather_dict["Cities"].append(cities[city_index])
                weather_dict["Country"].append(weather_response['sys']['country'])          
                weather_dict["Latitude"].append(weather_response['coord']['lat'])
                weather_dict["Humidity"].append(weather_response['main']['humidity'])
                weather_dict["Max. Temperature"].append(weather_response['main']['temp_max'])
                weather_dict["Cloudiness"].append(weather_response['clouds']['all'])
                weather_dict["Wind Speed"].append(weather_response['wind']['speed']) 
            except KeyError:
                     print(f"Data not complete for {cities[city_index]}..so skipping..")
                
            if (record_count%50==0):
                set_count+=1 
                record_count=1
            else:    
                record_count+=1

print("-----------------------------\n Data Retrieval Complete \n-----------------------------")
# Out:
#  Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kisujszallas
# Processing Record 1 of Set 1 | kisujszallas
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=rockland
# Processing Record 2 of Set 1 | rockland
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=taulov
# Processing Record 3 of Set 1 | taulov
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=severo-kurilsk
# Processing Record 4 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=khatanga
# Processing Record 5 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bambous%20virieux
# Processing Record 6 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sukhobezvodnoye
# Processing Record 7 of Set 1 | sukhobezvodnoye
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=atuona
# Processing Record 8 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tuktoyaktuk
# Processing Record 9 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nikolskoye
# Processing Record 10 of Set 1 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=camacha
# Processing Record 11 of Set 1 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=inuvik
# Processing Record 12 of Set 1 | inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=dicabisagan
# Processing Record 13 of Set 1 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=yellowknife
# Processing Record 14 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hobart
# Processing Record 15 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=uttaradit
# Processing Record 16 of Set 1 | uttaradit
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=souillac
# Processing Record 17 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saint-pierre
# Processing Record 18 of Set 1 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=beira
# Processing Record 19 of Set 1 | beira
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ushuaia
# Processing Record 20 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=broken%20hill
# Processing Record 21 of Set 1 | broken hill
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cidreira
# Processing Record 22 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=albany
# Processing Record 23 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=avarua
# Processing Record 24 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hegra
# Processing Record 25 of Set 1 | hegra
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vaini
# Processing Record 26 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mahebourg
# Processing Record 27 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kavieng
# Processing Record 28 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bluff
# Processing Record 29 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pilar
# Processing Record 30 of Set 1 | pilar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=esperance
# Processing Record 31 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maragogi
# Processing Record 32 of Set 1 | maragogi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=redmond
# Processing Record 33 of Set 1 | redmond
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cape%20town
# Processing Record 34 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=khandyga
# Processing Record 35 of Set 1 | khandyga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=georgetown
# Processing Record 36 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ilulissat
# Processing Record 37 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chokurdakh
# Processing Record 38 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bredasdorp
# Processing Record 39 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=luderitz
# Processing Record 40 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=rikitea
# Processing Record 41 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sorvag
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=arraial%20do%20cabo
# Processing Record 42 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=manadhoo
# Processing Record 43 of Set 1 | manadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=codrington
# Processing Record 44 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kudahuvadhoo
# Processing Record 45 of Set 1 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=torres
# Processing Record 46 of Set 1 | torres
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=provideniya
# Processing Record 47 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=svencionys
# Processing Record 48 of Set 1 | svencionys
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hvolsvollur
# Processing Record 49 of Set 1 | hvolsvollur
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=busselton
# Processing Record 50 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=punta%20arenas
# Processing Record 1 of Set 2 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=luwuk
# Processing Record 2 of Set 2 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=goldsboro
# Processing Record 3 of Set 2 | goldsboro
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mar%20del%20plata
# Processing Record 4 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=amarkantak
# Processing Record 5 of Set 2 | amarkantak
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cepu
# Processing Record 6 of Set 2 | cepu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chake%20chake
# Processing Record 7 of Set 2 | chake chake
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=asfi
# Processing Record 8 of Set 2 | asfi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jijiga
# Processing Record 9 of Set 2 | jijiga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=port%20alfred
# Processing Record 10 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ginir
# Processing Record 11 of Set 2 | ginir
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=east%20london
# Processing Record 12 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=itarema
# Processing Record 13 of Set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lalomanu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=talcahuano
# Processing Record 14 of Set 2 | talcahuano
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mys%20shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=santona
# Processing Record 15 of Set 2 | santona
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=port%20elizabeth
# Processing Record 16 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kuytun
# Processing Record 17 of Set 2 | kuytun
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=black%20river
# Processing Record 18 of Set 2 | black river
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sompeta
# Processing Record 19 of Set 2 | sompeta
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nelson%20bay
# Processing Record 20 of Set 2 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=port%20lincoln
# Processing Record 21 of Set 2 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=santa%20vitoria
# Processing Record 22 of Set 2 | santa vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hermanus
# Processing Record 23 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=new%20norfolk
# Processing Record 24 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lebu
# Processing Record 25 of Set 2 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mangrol
# Processing Record 26 of Set 2 | mangrol
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sola
# Processing Record 27 of Set 2 | sola
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=campana
# Processing Record 28 of Set 2 | campana
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=thap%20than
# Processing Record 29 of Set 2 | thap than
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chuy
# Processing Record 30 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=castro
# Processing Record 31 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cherskiy
# Processing Record 32 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=katsuura
# Processing Record 33 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=komsomolskiy
# Processing Record 34 of Set 2 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hilo
# Processing Record 35 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pevek
# Processing Record 36 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nara
# Processing Record 37 of Set 2 | nara
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=qaanaaq
# Processing Record 38 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tingo%20maria
# Processing Record 39 of Set 2 | tingo maria
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=faya
# Processing Record 40 of Set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jamestown
# Processing Record 41 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=olafsvik
# Processing Record 42 of Set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=longyearbyen
# Processing Record 43 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bilibino
# Processing Record 44 of Set 2 | bilibino
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=klyuchi
# Processing Record 45 of Set 2 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=san%20patricio
# Processing Record 46 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=skelleftea
# Processing Record 47 of Set 2 | skelleftea
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=thongwa
# Processing Record 48 of Set 2 | thongwa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=coquimbo
# Processing Record 49 of Set 2 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=juneau
# Processing Record 50 of Set 2 | juneau
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=laguna
# Processing Record 1 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kaputa
# Processing Record 2 of Set 3 | kaputa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=picos
# Processing Record 3 of Set 3 | picos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=amahai
# Processing Record 4 of Set 3 | amahai
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jalu
# Processing Record 5 of Set 3 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hami
# Processing Record 6 of Set 3 | hami
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lompoc
# Processing Record 7 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sao%20joao%20da%20barra
# Processing Record 8 of Set 3 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=byron%20bay
# Processing Record 9 of Set 3 | byron bay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sabla
# Processing Record 10 of Set 3 | sabla
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=warrnambool
# Processing Record 11 of Set 3 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hithadhoo
# Processing Record 12 of Set 3 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sinnamary
# Processing Record 13 of Set 3 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ust-kamchatsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saint%20george
# Processing Record 14 of Set 3 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hualmay
# Processing Record 15 of Set 3 | hualmay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=camocim
# Processing Record 16 of Set 3 | camocim
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mehamn
# Processing Record 17 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chamba
# Processing Record 18 of Set 3 | chamba
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=rosenberg
# Processing Record 19 of Set 3 | rosenberg
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=northam
# Processing Record 20 of Set 3 | northam
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lashio
# Processing Record 21 of Set 3 | lashio
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=helong
# Processing Record 22 of Set 3 | helong
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kysyl-syr
# Processing Record 23 of Set 3 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=weyburn
# Processing Record 24 of Set 3 | weyburn
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mount%20gambier
# Processing Record 25 of Set 3 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kasempa
# Processing Record 26 of Set 3 | kasempa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chapais
# Processing Record 27 of Set 3 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pasni
# Processing Record 28 of Set 3 | pasni
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bashtanka
# Processing Record 29 of Set 3 | bashtanka
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tiksi
# Processing Record 30 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=westport
# Processing Record 31 of Set 3 | westport
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maykain
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vanimo
# Processing Record 32 of Set 3 | vanimo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cayenne
# Processing Record 33 of Set 3 | cayenne
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=utete
# Processing Record 34 of Set 3 | utete
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cachoeira%20do%20sul
# Processing Record 35 of Set 3 | cachoeira do sul
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=petropavlovsk-kamchatskiy
# Processing Record 36 of Set 3 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ribeira%20grande
# Processing Record 37 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saskylakh
# Processing Record 38 of Set 3 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=barrow
# Processing Record 39 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=dargaville
# Processing Record 40 of Set 3 | dargaville
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mataura
# Processing Record 41 of Set 3 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=atar
# Processing Record 42 of Set 3 | atar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=carnarvon
# Processing Record 43 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bernardino%20de%20campos
# Processing Record 44 of Set 3 | bernardino de campos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=boyolangu
# Processing Record 45 of Set 3 | boyolangu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maulvi%20bazar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=muhos
# Processing Record 46 of Set 3 | muhos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sungai%20padi
# Processing Record 47 of Set 3 | sungai padi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=norman%20wells
# Processing Record 48 of Set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=upernavik
# Processing Record 49 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=seoul
# Processing Record 50 of Set 3 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=porto%20velho
# Processing Record 1 of Set 4 | porto velho
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jhanjharpur
# Processing Record 2 of Set 4 | jhanjharpur
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shumyachi
# Processing Record 3 of Set 4 | shumyachi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=isla%20mujeres
# Processing Record 4 of Set 4 | isla mujeres
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=fortuna
# Processing Record 5 of Set 4 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sioux%20lookout
# Processing Record 6 of Set 4 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=flinders
# Processing Record 7 of Set 4 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ponta%20do%20sol
# Processing Record 8 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hasaki
# Processing Record 9 of Set 4 | hasaki
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kibondo
# Processing Record 10 of Set 4 | kibondo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saint-philippe
# Processing Record 11 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=abnub
# Processing Record 12 of Set 4 | abnub
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lensk
# Processing Record 13 of Set 4 | lensk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=thompson
# Processing Record 14 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cabo%20san%20lucas
# Processing Record 15 of Set 4 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=airai
# Processing Record 16 of Set 4 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kruisfontein
# Processing Record 17 of Set 4 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kapaa
# Processing Record 18 of Set 4 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=broome
# Processing Record 19 of Set 4 | broome
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nanortalik
# Processing Record 20 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sobolevo
# Processing Record 21 of Set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=palmer
# Processing Record 22 of Set 4 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=salta
# Processing Record 23 of Set 4 | salta
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cortez
# Processing Record 24 of Set 4 | cortez
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bengkulu
# Processing Record 25 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=belushya%20guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chumphon
# Processing Record 26 of Set 4 | chumphon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=khandbari
# Processing Record 27 of Set 4 | khandbari
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vila%20velha
# Processing Record 28 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=grindavik
# Processing Record 29 of Set 4 | grindavik
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tecoanapa
# Processing Record 30 of Set 4 | tecoanapa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maxixe
# Processing Record 31 of Set 4 | maxixe
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bereda
# Processing Record 32 of Set 4 | bereda
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=haines%20junction
# Processing Record 33 of Set 4 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=gornopravdinsk
# Processing Record 34 of Set 4 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ratne
# Processing Record 35 of Set 4 | ratne
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ancud
# Processing Record 36 of Set 4 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=capitao%20poco
# Processing Record 37 of Set 4 | capitao poco
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shiyan
# Processing Record 38 of Set 4 | shiyan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ketchikan
# Processing Record 39 of Set 4 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kodiak
# Processing Record 40 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=severo-yeniseyskiy
# Processing Record 41 of Set 4 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maarianhamina
# Processing Record 42 of Set 4 | maarianhamina
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=puerto%20ayora
# Processing Record 43 of Set 4 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lata
# Processing Record 44 of Set 4 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mancio%20lima
# Processing Record 45 of Set 4 | mancio lima
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=port%20blair
# Processing Record 46 of Set 4 | port blair
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=waipawa
# Processing Record 47 of Set 4 | waipawa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pike%20creek
# Processing Record 48 of Set 4 | pike creek
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sao%20filipe
# Processing Record 49 of Set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sur
# Processing Record 50 of Set 4 | sur
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=eunice
# Processing Record 1 of Set 5 | eunice
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maputo
# Processing Record 2 of Set 5 | maputo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=clyde%20river
# Processing Record 3 of Set 5 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bethel
# Processing Record 4 of Set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pisco
# Processing Record 5 of Set 5 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=altamont
# Processing Record 6 of Set 5 | altamont
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=touros
# Processing Record 7 of Set 5 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cheremukhovo
# Processing Record 8 of Set 5 | cheremukhovo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tveit
# Processing Record 9 of Set 5 | tveit
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=terrace
# Processing Record 10 of Set 5 | terrace
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=wajima
# Processing Record 11 of Set 5 | wajima
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shagonar
# Processing Record 12 of Set 5 | shagonar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sorong
# Processing Record 13 of Set 5 | sorong
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=aldan
# Processing Record 14 of Set 5 | aldan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=camargo
# Processing Record 15 of Set 5 | camargo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kavaratti
# Processing Record 16 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vestmannaeyjar
# Processing Record 17 of Set 5 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=comodoro%20rivadavia
# Processing Record 18 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=del%20rio
# Processing Record 19 of Set 5 | del rio
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sorland
# Processing Record 20 of Set 5 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=gien
# Processing Record 21 of Set 5 | gien
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=santa%20marta
# Processing Record 22 of Set 5 | santa marta
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=gondar
# Processing Record 23 of Set 5 | gondar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vangaindrano
# Processing Record 24 of Set 5 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kamenka
# Processing Record 25 of Set 5 | kamenka
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=svetlogorsk
# Processing Record 26 of Set 5 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=corn%20island
# Processing Record 27 of Set 5 | corn island
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mastic%20beach
# Processing Record 28 of Set 5 | mastic beach
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=riohacha
# Processing Record 29 of Set 5 | riohacha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ahipara
# Processing Record 30 of Set 5 | ahipara
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=guerrero%20negro
# Processing Record 31 of Set 5 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cap%20malheureux
# Processing Record 32 of Set 5 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=dabat
# Processing Record 33 of Set 5 | dabat
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=polunochnoye
# Processing Record 34 of Set 5 | polunochnoye
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=puerto%20del%20rosario
# Processing Record 35 of Set 5 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tonantins
# Processing Record 36 of Set 5 | tonantins
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=gubkinskiy
# Processing Record 37 of Set 5 | gubkinskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=isugod
# Processing Record 38 of Set 5 | isugod
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=oksfjord
# Processing Record 39 of Set 5 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=leningradskiy
# Processing Record 40 of Set 5 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=verkhoyansk
# Processing Record 41 of Set 5 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vila
# Processing Record 42 of Set 5 | vila
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=fort%20nelson
# Processing Record 43 of Set 5 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=abu%20samrah
# Processing Record 44 of Set 5 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=torbay
# Processing Record 45 of Set 5 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=morro%20bay
# Processing Record 46 of Set 5 | morro bay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sibolga
# Processing Record 47 of Set 5 | sibolga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shaunavon
# Processing Record 48 of Set 5 | shaunavon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kuopio
# Processing Record 49 of Set 5 | kuopio
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nador
# Processing Record 50 of Set 5 | nador
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ampanihy
# Processing Record 1 of Set 6 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ramnagar
# Processing Record 2 of Set 6 | ramnagar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=osypenko
# Processing Record 3 of Set 6 | osypenko
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=umba
# Processing Record 4 of Set 6 | umba
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=millington
# Processing Record 5 of Set 6 | millington
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=leh
# Processing Record 6 of Set 6 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=warmbad
# Processing Record 7 of Set 6 | warmbad
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vila%20franca%20do%20campo
# Processing Record 8 of Set 6 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=karratha
# Processing Record 9 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ust-nera
# Processing Record 10 of Set 6 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ambilobe
# Processing Record 11 of Set 6 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=los%20llanos%20de%20aridane
# Processing Record 12 of Set 6 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sulangan
# Processing Record 13 of Set 6 | sulangan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=quatre%20cocos
# Processing Record 14 of Set 6 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nicoya
# Processing Record 15 of Set 6 | nicoya
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bonavista
# Processing Record 16 of Set 6 | bonavista
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=winslow
# Processing Record 17 of Set 6 | winslow
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ossora
# Processing Record 18 of Set 6 | ossora
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=champerico
# Processing Record 19 of Set 6 | champerico
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bunog
# Processing Record 20 of Set 6 | bunog
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=faanui
# Processing Record 21 of Set 6 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chirgaon
# Processing Record 22 of Set 6 | chirgaon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=adre
# Processing Record 23 of Set 6 | adre
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bukama
# Processing Record 24 of Set 6 | bukama
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=navolato
# Processing Record 25 of Set 6 | navolato
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=butaritari
# Processing Record 26 of Set 6 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vitim
# Processing Record 27 of Set 6 | vitim
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maniitsoq
# Processing Record 28 of Set 6 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kloulklubed
# Processing Record 29 of Set 6 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vryheid
# Processing Record 30 of Set 6 | vryheid
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=meyungs
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shu
# Processing Record 31 of Set 6 | shu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=korla
# Processing Record 32 of Set 6 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tautira
# Processing Record 33 of Set 6 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=atambua
# Processing Record 34 of Set 6 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=guiratinga
# Processing Record 35 of Set 6 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ushtobe
# Processing Record 36 of Set 6 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cascais
# Processing Record 37 of Set 6 | cascais
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=santa%20cruz
# Processing Record 38 of Set 6 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=livingston
# Processing Record 39 of Set 6 | livingston
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=catabangan
# Processing Record 40 of Set 6 | catabangan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kazalinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=necochea
# Processing Record 41 of Set 6 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kutum
# Processing Record 42 of Set 6 | kutum
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=manono
# Processing Record 43 of Set 6 | manono
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=batagay
# Processing Record 44 of Set 6 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bijie
# Processing Record 45 of Set 6 | bijie
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=formoso%20do%20araguaia
# City not found. Skipping...
# ...
# Processing Record 49 of Set 10 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=shimoda
# Processing Record 50 of Set 10 | shimoda
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bougouni
# Processing Record 1 of Set 11 | bougouni
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saleaula
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bjornevatn
# Processing Record 2 of Set 11 | bjornevatn
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=peniche
# Processing Record 3 of Set 11 | peniche
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hailar
# Processing Record 4 of Set 11 | hailar
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saint%20pete%20beach
# Processing Record 5 of Set 11 | saint pete beach
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jardim
# Processing Record 6 of Set 11 | jardim
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=yarovoye
# Processing Record 7 of Set 11 | yarovoye
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=middlebury
# Processing Record 8 of Set 11 | middlebury
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chuhar%20kana
# Processing Record 9 of Set 11 | chuhar kana
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mapiri
# Processing Record 10 of Set 11 | mapiri
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=anadyr
# Processing Record 11 of Set 11 | anadyr
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=akyab
# Processing Record 12 of Set 11 | akyab
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=atsiki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=warrington
# Processing Record 13 of Set 11 | warrington
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hobyo
# Processing Record 14 of Set 11 | hobyo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=matagami
# Processing Record 15 of Set 11 | matagami
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=geraldton
# Processing Record 16 of Set 11 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kosikha
# Processing Record 17 of Set 11 | kosikha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lavrentiya
# Processing Record 18 of Set 11 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=kungurtug
# Processing Record 19 of Set 11 | kungurtug
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hofn
# Processing Record 20 of Set 11 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tamuin
# Processing Record 21 of Set 11 | tamuin
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=coaticook
# Processing Record 22 of Set 11 | coaticook
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=youghal
# Processing Record 23 of Set 11 | youghal
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=guapi
# Processing Record 24 of Set 11 | guapi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=dolores
# Processing Record 25 of Set 11 | dolores
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=rondonopolis
# Processing Record 26 of Set 11 | rondonopolis
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cockburn%20town
# Processing Record 27 of Set 11 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bahia%20honda
# Processing Record 28 of Set 11 | bahia honda
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=spetsai
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=college
# Processing Record 29 of Set 11 | college
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=itapuranga
# Processing Record 30 of Set 11 | itapuranga
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=vylkove
# Processing Record 31 of Set 11 | vylkove
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=buctzotz
# Processing Record 32 of Set 11 | buctzotz
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=caravelas
# Processing Record 33 of Set 11 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=khromtau
# Processing Record 34 of Set 11 | khromtau
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=collie
# Processing Record 35 of Set 11 | collie
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=alofi
# Processing Record 36 of Set 11 | alofi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=sharjah
# Processing Record 37 of Set 11 | sharjah
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=lakes%20entrance
# Processing Record 38 of Set 11 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=katherine
# Processing Record 39 of Set 11 | katherine
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tuatapere
# Processing Record 40 of Set 11 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=hvammstangi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=abidjan
# Processing Record 41 of Set 11 | abidjan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tasbuget
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bilma
# Processing Record 42 of Set 11 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=oktyabrskoye
# Processing Record 43 of Set 11 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=portland
# Processing Record 44 of Set 11 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bouna
# Processing Record 45 of Set 11 | bouna
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=flin%20flon
# Processing Record 46 of Set 11 | flin flon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=galiwinku
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maraa
# Processing Record 47 of Set 11 | maraa
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=chazuta
# Processing Record 48 of Set 11 | chazuta
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=malakal
# Processing Record 49 of Set 11 | malakal
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=makakilo%20city
# Processing Record 50 of Set 11 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=taltal
# Processing Record 1 of Set 12 | taltal
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=caraballeda
# Processing Record 2 of Set 12 | caraballeda
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=eyl
# Processing Record 3 of Set 12 | eyl
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=cassino
# Processing Record 4 of Set 12 | cassino
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=zasheyek
# Processing Record 5 of Set 12 | zasheyek
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=moerai
# Processing Record 6 of Set 12 | moerai
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=asayita
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=amaigbo
# Processing Record 7 of Set 12 | amaigbo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=avondale
# Processing Record 8 of Set 12 | avondale
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=alekseyevka
# Processing Record 9 of Set 12 | alekseyevka
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tlapa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=freeport
# Processing Record 10 of Set 12 | freeport
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=la%20peca
# Processing Record 11 of Set 12 | la peca
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jaisalmer
# Processing Record 12 of Set 12 | jaisalmer
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maturin
# Processing Record 13 of Set 12 | maturin
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=grong
# Processing Record 14 of Set 12 | grong
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=jos
# Processing Record 15 of Set 12 | jos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=dhidhdhoo
# Processing Record 16 of Set 12 | dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=constitucion
# Processing Record 17 of Set 12 | constitucion
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=caibiran
# Processing Record 18 of Set 12 | caibiran
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=colacling
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=falmouth
# Processing Record 19 of Set 12 | falmouth
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=manama
# Processing Record 20 of Set 12 | manama
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=paithan
# Processing Record 21 of Set 12 | paithan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=traralgon
# Processing Record 22 of Set 12 | traralgon
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=assemini
# Processing Record 23 of Set 12 | assemini
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=bracebridge
# Processing Record 24 of Set 12 | bracebridge
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=luganville
# Processing Record 25 of Set 12 | luganville
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=nouadhibou
# Processing Record 26 of Set 12 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=luanda
# Processing Record 27 of Set 12 | luanda
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=marawi
# Processing Record 28 of Set 12 | marawi
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=pagudpud
# Processing Record 29 of Set 12 | pagudpud
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=yaan
# Processing Record 30 of Set 12 | yaan
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=abeokuta
# Processing Record 31 of Set 12 | abeokuta
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=potiskum
# Processing Record 32 of Set 12 | potiskum
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=mudgee
# Processing Record 33 of Set 12 | mudgee
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=maceio
# Processing Record 34 of Set 12 | maceio
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=beloha
# Processing Record 35 of Set 12 | beloha
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tilichiki
# Processing Record 36 of Set 12 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=saint-augustin
# Processing Record 37 of Set 12 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=ostrovnoy
# Processing Record 38 of Set 12 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=la%20ronge
# Processing Record 39 of Set 12 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=acapulco
# Processing Record 40 of Set 12 | acapulco
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=anyang
# Processing Record 41 of Set 12 | anyang
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=simpang
# Processing Record 42 of Set 12 | simpang
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=tres%20arroyos
# Processing Record 43 of Set 12 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=piacabucu
# Processing Record 44 of Set 12 | piacabucu
# http://api.openweathermap.org/data/2.5/weather?appid=25b31587314bafeb87fd9c4ef69d2cdb&units=metric&q=demba
# Processing Record 45 of Set 12 | demba
# -----------------------------
#  Data Retrieval Complete
# -----------------------------

# %%
weather_df = pd.DataFrame(weather_dict) 
#Data cleaning
weather_df = weather_df[weather_df['Humidity']<=100]  # -- few weather reports have erroneous data of more than 100% humidity
#Save to csv file
weather_df.to_csv("Weather_data.csv")

# %%
#Select data from weather for a single date
date_today = max(weather_df["Date"].value_counts().keys())  #-- to select the date which most of the weather data belongs to.
weather_today = weather_df.loc[weather_df["Date"]==date_today,:]  #-- to filter data for single date 
weather_today.head(10)
# Out:
#             Cities Country  Latitude      Date  Max. Temperature  Humidity  \
# 0     kisujszallas      HU   47.2167  12-12-21              2.01        97
# 1         rockland      US   41.1668  12-12-21              6.35        57
# 2           taulov      DK   55.5458  12-12-21              7.84        93
# 3   severo-kurilsk      RU   50.6789  12-12-21              1.17        81
# 4         khatanga      RU   71.9667  12-12-21            -44.46        99
# 5  bambous virieux      MU  -20.3428  12-12-21             24.14        78
# 6  sukhobezvodnoye      RU   57.0491  12-12-21            -10.50        91
# 7           atuona      PF   -9.8000  12-12-21             26.10        80
# 8      tuktoyaktuk      CA   69.4541  12-12-21            -21.00        77
# 9       nikolskoye      RU   59.7035  12-12-21             -4.06        99
#
#    Cloudiness  Wind Speed
# 0         100        4.21
# 1           0        0.89
# 2          46        2.58
# 3          27        2.61
# 4          82        2.42
# 5          40        2.57
# 6          80        2.77
# 7          83        7.79
# 8          90        8.75
# 9         100        0.68
